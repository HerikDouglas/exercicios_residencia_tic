# %% [markdown]
# <a href="https://colab.research.google.com/github/HerikDouglas/exercicios_residencia_tic/blob/main/oficina_aula_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Oficina - Aula 4: Desenvolvendo um projeto de análise de dados em Python

# %%
import numpy as np
import pandas as pd

#Use a lista de números: [12, 45, 67, 23, 89, 34, 22, 90, 56, 78].

lista = np.array([12, 45, 67, 23, 89, 34, 22, 90, 56, 78])

#Calcule a média dos números usando a biblioteca numpy.

media = np.mean(lista)
print("A média dos números é", media)

#Identifique os números que são maiores que a média.
#Armazene os números maiores que a média em um DataFrame do pandas.

lista_maior_que_media = []

for num in lista:
  if num > media:
    lista_maior_que_media.append(num)

df = pd.DataFrame(lista_maior_que_media, columns=['ValoresMaioresQueMedia'])

#Salve o DataFrame em um arquivo CSV chamado "numeros_maiores_que_media.csv"

df.to_csv('numeros_maiores_que_media.csv', index=False)
# Out:
# A média dos números é 51.6
#    ValoresMaioresQueMedia
# 0                      67
# 1                      89
# 2                      90
# 3                      56
# 4                      78
